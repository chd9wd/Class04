# %% [markdown]
# # Basic python calculations
#
# We can use Python like a Calculator

# %%
37+53
# Out:
# 90

# %%
3600/23
# Out:
# 156.52173913043478

# %%
r=1

area=3.14*r**2   # '**' to the power of
print(area)
# Out:
# 3.14

# %%
number=3
number_squared=number**2
print(number_squared)
number_cubed=number**3
print(number_cubed)
# Out:
# 9
# 27

# %%
#Let's make a multiplication table using loops
#This is called a 'for' loop  
#Can you understand the notation?
#Actually these are 'nested for' loops - one inside of the other.
for i in range(1, 13):
    for j in range(i,13):
       print(i, 'x', j, '=', i*j)
# Out:
# 1 x 1 = 1
# 1 x 2 = 2
# 1 x 3 = 3
# 1 x 4 = 4
# 1 x 5 = 5
# 1 x 6 = 6
# 1 x 7 = 7
# 1 x 8 = 8
# 1 x 9 = 9
# 1 x 10 = 10
# 1 x 11 = 11
# 1 x 12 = 12
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20
# 2 x 11 = 22
# 2 x 12 = 24
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30
# 3 x 11 = 33
# 3 x 12 = 36
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40
# 4 x 11 = 44
# 4 x 12 = 48
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
# 5 x 11 = 55
# 5 x 12 = 60
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60
# 6 x 11 = 66
# 6 x 12 = 72
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70
# 7 x 11 = 77
# 7 x 12 = 84
# 8 x 8 = 64
# 8 x 9 = 72
# 8 x 10 = 80
# 8 x 11 = 88
# 8 x 12 = 96
# 9 x 9 = 81
# 9 x 10 = 90
# 9 x 11 = 99
# 9 x 12 = 108
# 10 x 10 = 100
# 10 x 11 = 110
# 10 x 12 = 120
# ...

# %% [markdown]
# For more complex math we should __import the math module__:

# %%
import math
math.__doc__
# Out:
# 'This module provides access to the mathematical functions\ndefined by the C standard.'

# %% [markdown]
# __This is our first use of a module!__  If we import the module this way, then we have to call its functions like :  math.functionname().  Most modules and functions will have "doc strings" which we can access with the '__doc__' attribute.  We will learn more about "doc strings" later in the course.
#
#
# What functions are available in the math module you ask?  **We can use the python built in 'dir' attribute to list all of the functions in a Python module:**

# %%
dir(math)
# Out:
# ['__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc']

# %% [markdown]
# Many of those methods should be obvious to you, but you can find out what they all are with the math module documentation.  A Google seach would turn up this link:  https://docs.python.org/3/library/math.html
#
# Browse this documentation.  **One of the most important thing we will learn in this class is how to use the documentation of the python modules!**
#
# Let's try a few of the fuctions in the math module..

# %%
math.sqrt.__doc__  #Let's check the doc string...
# Out:
# 'Return the square root of x.'

# %% [markdown]
# Let's try it...

# %%
math.sqrt(9)
# Out:
# 3.0

# %%
math.remainder(10,3)
# Out:
# 1.0

# %%
math.pow(3,2)  #Note:  this does the same thing as 3**2
# Out:
# 9

# %%
3**2  #Note: this does the same thing as math.pow(3,2)
# Out:
# 9

# %%
math.pi
# Out:
# 3.141592653589793

# %% [markdown]
# FYI: Operator precedence in python follows the PEMDAS rule for arithmetic expressions. The precedence of operators is listed below in a high to low manner.
#
# Firstly, parantheses will be evaluated, then exponentiation and so on.
#
#     P – Parentheses
#     E – Exponentiation
#     M – Multiplication
#     D – Division
#     A – Addition
#     S – Subtraction
# Let's see an example...

# %%
a=3*2+3
b=3*(2+3)
print(a,b)
# Out:
# 9 15

# %% [markdown]
# # Exercise 1
#
# Calculate 5 factorial.  Hint: there is a function for how to do this in the math module.  Read the documentation and figure out how to do it.  Also, do it by hand, and make sure you get the same answer.

# %%
# Put your code here

# %% [markdown]
# # Exercise 2
#
# Calculate the sin and cosin of 0,pi/2,pi,3pi/2, and 2pi.  Remember the unit circle from trig?
#
# ![Image](unit_circle.png)

# %%
#put your code here

# %% [markdown]
# That is it for today!  Make sure to push your work to GitHub.

# %% [markdown]
# __Bonus__:  see that the iPython 'magic' command works in a Jupyter notebook!

# %%
# %run hello.py
# Out:
#  Hello Python Multiverse!
